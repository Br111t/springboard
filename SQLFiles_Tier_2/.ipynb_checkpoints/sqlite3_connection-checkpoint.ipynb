# %% [markdown]
# PART 2: SQLite
#
# Export the country club data from PHPMyAdmin, and connect to a local SQLite instance from Jupyter notebook
# for the following questions.
#
# 1. Create a database
# 2. Donwload data from mysql
# 3. Create table with the donwloaded data
#
# Export the country club data from PHPMyAdmin, and connect to a local SQLite instance from Jupyter notebook
# for the following questions.

# %%
import sqlite3
import pandas as pd

# %%
#QUESTIONS:


#Q10: Produce a list of facilities with a total revenue less than 1000.
#The output of facility name and total revenue, sorted by revenue. Remember
#that there's a different cost for guests and members!

#facility name, total revenue

conn = sqlite3.connect('sqlite_db_pythonsqlite.db')
query10 = '''SELECT DISTINCT f.`name` ,
	CASE WHEN b.`memid` =0
		THEN f.`guestcost` * b.`slots`
	ELSE f.`membercost` * b.`slots`
		END AS total_revenue
FROM `Members` AS m, `Facilities` AS f, `Bookings` AS b
WHERE f.`facid` = b.`facid`
	AND m.`memid` = b.`memid`
HAVING total_revenue <1000
ORDER BY total_revenue DESC;'''

df10 = pd.read_sql_query(query10, conn)
df10
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# OperationalError: a GROUP BY clause is required before HAVING
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-2-03fe6c0c03cd> in <module>
#      20 ORDER BY total_revenue DESC;'''
#      21
# ---> 22 df10 = pd.read_sql_query(query10, conn)
#      23 df10
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     375     """
#     376     pandas_sql = pandasSQL_builder(con)
# --> 377     return pandas_sql.read_query(
#     378         sql,
#     379         index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1725
#    1726         args = _convert_params(sql, params)
# -> 1727         cursor = self.execute(*args)
#    1728         columns = [col_desc[0] for col_desc in cursor.description]
#    1729
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1691
#    1692             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1693             raise ex from exc
#    1694
#    1695     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT DISTINCT f.`name` ,
# 	CASE WHEN b.`memid` =0
# 		THEN f.`guestcost` * b.`slots`
# 	ELSE f.`membercost` * b.`slots`
# 		END AS total_revenue
# FROM `Members` AS m, `Facilities` AS f, `Bookings` AS b
# WHERE f.`facid` = b.`facid`
# 	AND m.`memid` = b.`memid`
# HAVING total_revenue <1000
# ORDER BY total_revenue DESC;': a GROUP BY clause is required before HAVING

# %%
#Q11: Produce a report of members and who recommended them in alphabetic surname,firstname order'''

query11 = '''SELECT m.`memid` , CONCAT( m.`firstname` , " ", m.`surname` ) AS member, m.`recommendedby`, 
	CASE WHEN m.`recommendedby` = 0 THEN "notRecommended"
	ELSE CONCAT( r.`firstname` , " ", r.`surname` ) END AS rMember
FROM `Members` AS m
JOIN `Members` AS r ON r.`memid` = m.`recommendedby`'''

df11 = pd.read_sql_query(query11, conn)
df11
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# OperationalError: no such function: CONCAT
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-3-28916ce9e5c6> in <module>
#       7 JOIN `Members` AS r ON r.`memid` = m.`recommendedby`'''
#       8
# ----> 9 df11 = pd.read_sql_query(query11, conn)
#      10 df11
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     375     """
#     376     pandas_sql = pandasSQL_builder(con)
# --> 377     return pandas_sql.read_query(
#     378         sql,
#     379         index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1725
#    1726         args = _convert_params(sql, params)
# -> 1727         cursor = self.execute(*args)
#    1728         columns = [col_desc[0] for col_desc in cursor.description]
#    1729
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1691
#    1692             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1693             raise ex from exc
#    1694
#    1695     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT m.`memid` , CONCAT( m.`firstname` , " ", m.`surname` ) AS member, m.`recommendedby`,
# 	CASE WHEN m.`recommendedby` = 0 THEN "notRecommended"
# 	ELSE CONCAT( r.`firstname` , " ", r.`surname` ) END AS rMember
# FROM `Members` AS m
# JOIN `Members` AS r ON r.`memid` = m.`recommendedby`': no such function: CONCAT

# %%
#Q12: Find the facilities with their usage by member, but not guests */

query12  = '''SELECT DISTINCT f.`name` AS Facility, b.`memid`, COUNT( b.`memid` ) AS useCount
FROM `Facilities` AS f, `Bookings` AS b
WHERE f.`facid` = b.`facid`
AND b.`memid` >0
GROUP BY b.`memid`
ORDER BY Facility, b.`memid`'''

df12 = pd.read_sql_query(query12, conn)
df12
# Out:
#            Facility  memid  useCount
# 0   Badminton Court      7       117
# 1   Badminton Court     15       120
# 2   Badminton Court     21       126
# 3   Badminton Court     26        14
# 4   Badminton Court     29        41
# 5   Badminton Court     30        16
# 6   Badminton Court     36         7
# 7    Massage Room 1      3       408
# 8    Massage Room 1      4       159
# 9    Massage Room 1     14        89
# 10   Massage Room 2     20        72
# 11    Snooker Table     17        71
# 12    Snooker Table     22        53
# 13    Snooker Table     27        20
# 14    Snooker Table     33        16
# 15     Table Tennis      1       261
# 16     Table Tennis     13        80
# 17   Tennis Court 1      2       210
# 18   Tennis Court 1      5       163
# 19   Tennis Court 1     10       131
# 20   Tennis Court 1     12       118
# 21   Tennis Court 1     28        34
# 22   Tennis Court 1     35        15
# 23   Tennis Court 2      6       176
# 24   Tennis Court 2      8       188
# 25   Tennis Court 2      9       104
# 26   Tennis Court 2     11       115
# 27   Tennis Court 2     16       166
# 28   Tennis Court 2     24        70

# %%
#Q13: Find the facilities usage by month, but not guests

query13 = '''SELECT DISTINCT f.`name` AS Facility , MONTH( `starttime` ) AS month , COUNT( * ) AS useByMonth
FROM `Bookings` AS b, `Facilities` AS f
WHERE YEAR( `starttime` ) = '2012'
AND b.`memid` >0
GROUP BY facility, month'''

df13 = pd.read_sql_query(query13, conn)
df13
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# OperationalError: no such function: MONTH
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-5-96428584ce36> in <module>
#       7 GROUP BY facility, month'''
#       8
# ----> 9 df13 = pd.read_sql_query(query13, conn)
#      10 df13
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     375     """
#     376     pandas_sql = pandasSQL_builder(con)
# --> 377     return pandas_sql.read_query(
#     378         sql,
#     379         index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1725
#    1726         args = _convert_params(sql, params)
# -> 1727         cursor = self.execute(*args)
#    1728         columns = [col_desc[0] for col_desc in cursor.description]
#    1729
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1691
#    1692             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1693             raise ex from exc
#    1694
#    1695     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT DISTINCT f.`name` AS Facility , MONTH( `starttime` ) AS month , COUNT( * ) AS useByMonth
# FROM `Bookings` AS b, `Facilities` AS f
# WHERE YEAR( `starttime` ) = '2012'
# AND b.`memid` >0
# GROUP BY facility, month': no such function: MONTH
